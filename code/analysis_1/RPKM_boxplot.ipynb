# %% [markdown]
# This script plot the difference between WT and CUX1 KD ATAC seq signal in human CD34+ HSPC for the CUX1-promotor bound loops and non-interacting loops. The loops are identified from CD34 HiC in Zhang 2020

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy

# %%
os.chdir("/.../CD34_HiC_CUX1_integration/data/analysis_1_results")

# %% [markdown]
# import the count matrix from computeMatrix

# %%
interact = pd.read_csv("CD34_ATAC_CUX1_interacting_loops_Heatmap_values.txt",header = 0,sep = "\t")
non_interact = pd.read_csv("CD34_ATAC_non_CUX1_interacting_loops_Heatmap_values.txt",header = 0,sep = "\t")

# %%
interact
# Out:
#      bamCompare CD34 ATAC KD RPKM  bamCompare CD34 ATAC KD RPKM.1  \
# 0                          0.5904                          0.3936
# 1                          0.3936                          0.5904
# 2                          0.1968                          0.0000
# 3                          0.0000                          0.1855
# 4                          0.3711                          0.5679
# ..                            ...                             ...
# 267                        0.7647                          0.9615
# 268                        0.4864                          0.2839
# 269                        1.1360                          1.2400
# 270                        0.9277                          1.1250
# 271                        2.8510                          3.2110
#
#      bamCompare CD34 ATAC KD RPKM.2  bamCompare CD34 ATAC KD RPKM.3  \
# 0                            0.1968                          0.1855
# 1                            0.3936                          0.3823
# 2                            0.1855                          0.3711
# 3                            0.7534                          1.7150
# 4                            0.5792                          0.5904
# ..                              ...                             ...
# 267                          0.8631                          0.7647
# 268                          0.1855                          0.2783
# 269                          1.1580                          1.2790
# 270                          1.3210                          1.5180
# 271                          3.1230                          1.8890
#
#      bamCompare CD34 ATAC KD RPKM.4  bamCompare CD34 ATAC KD RPKM.5  \
# 0                            0.3711                          0.4638
# 1                            0.3711                          0.3711
# 2                            0.3711                          0.1855
# 3                            3.2670                          4.9280
# 4                            0.3936                          0.1968
# ..                              ...                             ...
# 267                          0.7647                          0.5792
# 268                          0.5679                          0.9502
# 269                          1.7490                          2.5020
# 270                          1.3330                          1.1580
# 271                          0.8518                          0.8631
#
#      bamCompare CD34 ATAC KD RPKM.6  bamCompare CD34 ATAC KD RPKM.7  \
# 0                            0.5566                          0.5566
# 1                            0.1855                          0.0000
# 2                            0.0000                          0.0000
# 3                            6.5790                         10.9200
# 4                            0.0000                          0.1968
# ..                              ...                             ...
# 267                          0.6776                          0.7647
# 268                          1.7370                          2.3170
# 269                          2.9720                          2.9830
# 270                          1.3660                          1.5630
# 271                          1.4540                          2.3280
#
#      bamCompare CD34 ATAC KD RPKM.8  bamCompare CD34 ATAC KD RPKM.9  ...  \
# 0                            0.6494                          0.3711  ...
# 1                            0.0000                          0.0000  ...
# 2                            0.0000                          0.0000  ...
# 3                           18.0100                         24.6100  ...
# 4                            0.5904                          0.9840  ...
# ..                              ...                             ...  ...
# 267                          0.9502                          0.7534  ...
# 268                          3.2560                          2.6540  ...
# 269                          2.5250                          2.3500  ...
# 270                          1.6390                          1.3330  ...
# 271                          2.1420                          2.0440  ...
#
#      bamCompare CD34 ATAC WT RPKM.190  bamCompare CD34 ATAC WT RPKM.191  \
# 0                              0.4547                            0.9093
# 1                              1.4230                            0.7708
# 2                              3.4790                            4.0450
# 3                              1.0810                            1.3380
# 4                              0.2834                            0.0000
# ..                                ...                               ...
# 267                            0.3426                            0.5139
# 268                            2.0820                            0.9421
# 269                            0.3426                            0.1713
# 270                            1.5940                            1.8510
# 271                            0.3426                            0.6852
#
#      bamCompare CD34 ATAC WT RPKM.192  bamCompare CD34 ATAC WT RPKM.193  \
# 0                              1.0810                            0.9093
# 1                              0.7708                            0.8565
# 2                              5.1520                            5.6630
# 3                              0.8829                            0.4282
# 4                              0.0000                            0.3426
# ..                                ...                               ...
# 267                            0.5139                            0.7972
# 268                            0.3426                            0.0000
# 269                            0.1713                            0.5139
# 270                            1.7390                            1.5420
# 271                            0.6852                            0.6852
#
#      bamCompare CD34 ATAC WT RPKM.194  bamCompare CD34 ATAC WT RPKM.195  \
# 0                              0.7380                            0.8501
# 1                              1.1130                            1.2850
# 2                              7.2540                           12.5400
# 3                              0.5139                            0.7708
# 4                              0.6852                            0.8565
# ..                                ...                               ...
# 267                            1.2520                            1.2520
# 268                            0.0000                            0.0000
# 269                            0.8565                            1.3110
# 270                            1.4820                            1.1660
# 271                            0.3426                            0.3426
#
#      bamCompare CD34 ATAC WT RPKM.196  bamCompare CD34 ATAC WT RPKM.197  \
# 0                              0.5667                            0.2834
# 1                              1.2850                            1.4560
# 2                             20.1300                           25.7400
# 3                              1.0280                            0.8565
# 4                              0.7972                            0.4547
# ..                                ...                               ...
# 267                            0.9685                            0.3426
# 268                            0.0000                            0.0000
# 269                            1.9900                            2.5570
# 270                            0.9093                            0.7116
# 271                            0.3426                            0.5139
#
#      bamCompare CD34 ATAC WT RPKM.198  bamCompare CD34 ATAC WT RPKM.199
# 0                              0.1713                            0.3426
# 1                              1.6270                            2.3920
# 2                             27.6300                           31.9900
# 3                              1.1400                            1.4230
# 4                              0.2834                            0.0000
# ..                                ...                               ...
# 267                            0.1713                            0.4547
# 268                            0.0000                            0.0000
# 269                            2.1020                            1.8190
# 270                            1.2520                            1.3640
# 271                            0.5139                            0.7972
#
# [272 rows x 400 columns]

# %%
non_interact
# Out:
#       bamCompare CD34 ATAC KD RPKM  bamCompare CD34 ATAC KD RPKM.1  \
# 0                           0.5904                          0.5904
# 1                           1.6920                          1.8890
# 2                           2.1540                          1.8470
# 3                           0.0000                          0.1968
# 4                           0.5679                          0.1855
# ...                            ...                             ...
# 4530                        1.3330                          0.8575
# 4531                        0.1968                          0.3936
# 4532                        0.3711                          0.3711
# 4533                        7.1380                          7.2360
# 4534                        2.6990                          2.0330
#
#       bamCompare CD34 ATAC KD RPKM.2  bamCompare CD34 ATAC KD RPKM.3  \
# 0                             0.5904                          0.7872
# 1                             1.6330                          1.0710
# 2                             1.7370                          1.8360
# 3                             0.5904                          1.2790
# 4                             0.1855                          0.0000
# ...                              ...                             ...
# 4530                          0.6663                          0.6776
# 4531                          0.5904                          0.3936
# 4532                          0.1855                          0.0000
# 4533                          6.8820                          5.1140
# 4534                          1.4650                          1.5740
#
#       bamCompare CD34 ATAC KD RPKM.4  bamCompare CD34 ATAC KD RPKM.5  \
# 0                             1.1700                          1.3660
# 1                             1.2680                          1.1580
# 2                             2.9940                          3.8570
# 3                             1.7600                          2.0330
# 4                             0.0000                          0.0000
# ...                              ...                             ...
# 4530                          0.6888                          0.8856
# 4531                          0.5904                          0.7872
# 4532                          0.1968                          0.3936
# 4533                          3.5900                          2.1370
# 4534                          2.4380                          3.3120
#
#       bamCompare CD34 ATAC KD RPKM.6  bamCompare CD34 ATAC KD RPKM.7  \
# 0                             0.9728                          0.3936
# 1                             1.1470                          1.4030
# 2                             4.0320                          3.6270
# 3                             1.5290                          1.0490
# 4                             0.0000                          0.0000
# ...                              ...                             ...
# 4530                          1.0710                          1.4540
# 4531                          1.3780                          1.1810
# 4532                          0.5904                          0.5792
# 4533                          1.7430                          1.8470
# 4534                          3.6890                          3.9670
#
#       bamCompare CD34 ATAC KD RPKM.8  bamCompare CD34 ATAC KD RPKM.9  ...  \
# 0                             0.0000                          0.0000  ...
# 1                             1.3040                          1.4140  ...
# 2                             3.7900                          3.8880  ...
# 3                             0.7760                          0.9840  ...
# 4                             0.1968                          0.3936  ...
# ...                              ...                             ...  ...
# 4530                          1.7490                          1.6620  ...
# 4531                          1.1810                          0.7872  ...
# 4532                          0.7647                          0.7647  ...
# 4533                          1.9460                          1.6500  ...
# 4534                          4.7200                          5.0860  ...
#
#       bamCompare CD34 ATAC WT RPKM.190  bamCompare CD34 ATAC WT RPKM.191  \
# 0                              20.2000                          15.07000
# 1                               0.1713                           0.08565
# 2                               0.6852                           0.77080
# 3                               1.4170                           0.56670
# 4                               0.0000                           0.00000
# ...                                ...                               ...
# 4530                            0.0000                           0.17130
# 4531                            0.0000                           0.00000
# 4532                            1.1330                           1.41700
# 4533                            0.6259                           0.73800
# 4534                            0.4547                           0.17130
#
#       bamCompare CD34 ATAC WT RPKM.192  bamCompare CD34 ATAC WT RPKM.193  \
# 0                              10.9100                            9.0930
# 1                               0.1713                            0.5139
# 2                               0.6852                            0.9950
# 3                               0.0000                            0.1713
# 4                               0.0000                            0.0000
# ...                                ...                               ...
# 4530                            0.3426                            0.7972
# 4531                            0.2834                            0.7380
# 4532                            1.4170                            1.0210
# 4533                            0.9093                            0.9685
# 4534                            0.3426                            0.5139
#
#       bamCompare CD34 ATAC WT RPKM.194  bamCompare CD34 ATAC WT RPKM.195  \
# 0                               7.3930                            5.1200
# 1                               1.0280                            1.1990
# 2                               1.0210                            1.1330
# 3                               0.3426                            0.6852
# 4                               0.0000                            0.0000
# ...                                ...                               ...
# 4530                            1.0810                            1.3640
# 4531                            0.9950                            0.9685
# 4532                            0.6259                            0.6852
# 4533                            1.3110                            1.2520
# 4534                            0.3426                            0.1713
#
#       bamCompare CD34 ATAC WT RPKM.196  bamCompare CD34 ATAC WT RPKM.197  \
# 0                               3.9830                           3.47200
# 1                               1.0280                           0.51390
# 2                               0.9357                           0.82370
# 3                               0.6852                           0.51390
# 4                               0.1713                           0.34260
# ...                                ...                               ...
# 4530                            1.3640                           0.90930
# 4531                            0.6852                           0.51390
# 4532                            1.0540                           1.33800
# 4533                            0.9950                           0.62590
# 4534                            0.0000                           0.08565
#
#       bamCompare CD34 ATAC WT RPKM.198  bamCompare CD34 ATAC WT RPKM.199
# 0                               3.6760                            3.5350
# 1                               0.1713                            0.1713
# 2                               0.7116                            0.5139
# 3                               0.1713                            0.0000
# 4                               0.5139                            0.3426
# ...                                ...                               ...
# 4530                            0.4547                            0.0000
# 4531                            0.3426                            0.1713
# 4532                            1.4500                            1.6210
# 4533                            0.5139                            1.1400
# 4534                            0.1713                            0.5403
#
# [4535 rows x 400 columns]

# %% [markdown]
# aggregate the RPKM values for all the bins(columns) for each region

# %%
interact_WT = interact.filter(regex = "WT").sum(axis = 1)
interact_KD = interact.filter(regex = "KD").sum(axis = 1)
interact_plot = pd.DataFrame({'WT':interact_WT,'KD':interact_KD})

# %%
non_interact_WT = non_interact.filter(regex = "WT").sum(axis = 1)
non_interact_KD = non_interact.filter(regex = "KD").sum(axis = 1)
non_interact_plot = pd.DataFrame({'WT':non_interact_WT,'KD':non_interact_KD})

# %%
scipy.stats.ttest_ind(interact_WT,interact_KD)
# Out:
# Ttest_indResult(statistic=2.276029276439668, pvalue=0.023233530546983894)
